# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Attrition data.csv')
df.head(5)
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel_Rarely                   Sales
# 1           2   31       Yes  Travel_Frequently  Research & Development
# 2           3   32        No  Travel_Frequently  Research & Development
# 3           4   38        No         Non-Travel  Research & Development
# 4           5   32        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# 1                10          1  Life Sciences              1  Female  ...
# 2                17          4          Other              1    Male  ...
# 3                 2          5  Life Sciences              1    Male  ...
# 4                10          1        Medical              1    Male  ...
#
#    TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %% [markdown]
# Education
# 1 'Below College' 2 'College' 3 'Bachelor' 4 'Master' 5 'Doctor'
#
# EnvironmentSatisfaction
# 1 'Low' 2 'Medium' 3 'High' 4 'Very High'
#
# JobInvolvement
# 1 'Low' 2 'Medium' 3 'High' 4 'Very High'
#
# JobSatisfaction
# 1 'Low' 2 'Medium' 3 'High' 4 'Very High'
#
# PerformanceRating
# 1 'Low' 2 'Good' 3 'Excellent' 4 'Outstanding'
#
# RelationshipSatisfaction
# 1 'Low' 2 'Medium' 3 'High' 4 'Very High'
#
# WorkLifeBalance
# 1 'Bad' 2 'Good' 3 'Better' 4 'Best'

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Age', 'Attrition', 'BusinessTravel', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'Gender', 'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance',
#        'JobInvolvement', 'PerformanceRating'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4410 non-null   int64
#  1   Age                      4410 non-null   int64
#  2   Attrition                4410 non-null   object
#  3   BusinessTravel           4410 non-null   object
#  4   Department               4410 non-null   object
#  5   DistanceFromHome         4410 non-null   int64
#  6   Education                4410 non-null   int64
#  7   EducationField           4410 non-null   object
#  8   EmployeeCount            4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
df.describe()
# Out:
#         EmployeeID          Age  DistanceFromHome    Education  EmployeeCount  \
# count  4410.000000  4410.000000       4410.000000  4410.000000         4410.0
# mean   2205.500000    36.923810          9.192517     2.912925            1.0
# std    1273.201673     9.133301          8.105026     1.023933            0.0
# min       1.000000    18.000000          1.000000     1.000000            1.0
# 25%    1103.250000    30.000000          2.000000     2.000000            1.0
# 50%    2205.500000    36.000000          7.000000     3.000000            1.0
# 75%    3307.750000    43.000000         14.000000     4.000000            1.0
# max    4410.000000    60.000000         29.000000     5.000000            1.0
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %% [markdown]
# droppig out the columns that conatain unique values

# %%
unique_value_columns = [col for col in df.columns if df[col].nunique() == 1]
unique_value_columns
df = df.drop(columns=unique_value_columns, axis=1)
df.columns
# Out:
# Index(['EmployeeID', 'Age', 'Attrition', 'BusinessTravel', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'Gender', 'JobLevel',
#        'JobRole', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'EnvironmentSatisfaction', 'JobSatisfaction',
#        'WorkLifeBalance', 'JobInvolvement', 'PerformanceRating'],
#       dtype='object')

# %%
df.shape
# Out:
# (4410, 26)

# %%
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns
categorical_columns = df.select_dtypes(include=['object', 'category']).columns

numeric_columns, categorical_columns
# Out:
# (Index(['EmployeeID', 'Age', 'DistanceFromHome', 'Education', 'JobLevel',
#         'MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike',
#         'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#         'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#         'EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance',
#         'JobInvolvement', 'PerformanceRating'],
#        dtype='object'),
#  Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#         'JobRole', 'MaritalStatus'],
#        dtype='object'))

# %%
fig, ax = plt.subplots(1,2, figsize=(12,6))

ax[0].pie(df.Attrition.value_counts(), labels=df.Attrition.unique(), autopct='%1.1f%%', startangle=140)
ax[0].set_title("Attrition distribution")

ax[1].bar(df.Attrition.unique(), df.Attrition.value_counts(), color=["darkblue", "darkorange"])
for bars in ax[1].containers:
    ax[1].bar_label(bars)

plt.title("Attribution distribution")
plt.show()

# %%
sns.histplot(df['Department'],color='lightblue')
# Out:
# <Axes: xlabel='Department', ylabel='Count'>

# %%
sns.histplot(df['MonthlyIncome'],kde=True,bins=50,color='lightgreen')
# Out:
# <Axes: xlabel='MonthlyIncome', ylabel='Count'>

# %%
sns.histplot(df['Education'])
plt.xticks([1,2,3,4,5])
# Out:
# ([<matplotlib.axis.XTick at 0x24f61aac2b0>,
# ...
#  [Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5')])

# %% [markdown]
# The most common level of education employees is 3 - 'Bachelor', the least common is 5 - 'Doctor'.

# %%
sns.histplot(df['Gender'])
# Out:
# <Axes: xlabel='Gender', ylabel='Count'>

# %%
sns.histplot(df['JobSatisfaction'])
plt.xticks([1,2,3,4])
# Out:
# ([<matplotlib.axis.XTick at 0x24f61b97970>,
# ...
#  [Text(1, 0, '1'), Text(2, 0, '2'), Text(3, 0, '3'), Text(4, 0, '4')])

# %%
sns.histplot(df['WorkLifeBalance'])
plt.xticks([1,2,3,4])
# Out:
# ([<matplotlib.axis.XTick at 0x24f660079d0>,
# ...
#  [Text(1, 0, '1'), Text(2, 0, '2'), Text(3, 0, '3'), Text(4, 0, '4')])

# %%
sns.histplot(df['DistanceFromHome'],bins=20)
# Out:
# <Axes: xlabel='DistanceFromHome', ylabel='Count'>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Attrition', y='JobSatisfaction', data=df, palette='Set2')
plt.title('Boxplot of JobSatisfaction by Attrition')
plt.xlabel('Attrition')
plt.ylabel('JobSatisfaction')
plt.show()

# %% [markdown]
# people who have the least job satisfaction index tend to leave and those with the highest satisfaction index tend to stay.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Attrition', y='DistanceFromHome', data=df, palette='Set2')
plt.title('Boxplot of DistanceFromHome by Attrition')
plt.xlabel('Attrition')
plt.ylabel('DistanceFromHome')
plt.show()

# %% [markdown]
# The distance from home does influence an employee's decision to leave the company. If the distance to work is more than 9 Distance Units from home, employees are more likely to change jobs.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Attrition', y='Age', data=df, palette='Set2')
plt.title('Boxplot of Age by Attrition')
plt.xlabel('Attrition')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# As expected, younger employees tend to be leave the company more often than older ones.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Attrition', y='MonthlyIncome', data=df, palette='Set2')
plt.title('Boxplot of MonthlyIncome by Attrition')
plt.xlabel('Attrition')
plt.ylabel('MonthlyIncome')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# We can also see that people who have higher income tend to stay at the company, monthly income affects attrition

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Attrition', y='PercentSalaryHike', data=df, palette='Set2')
plt.title('Boxplot of PercentSalaryHike by Attrition')
plt.xlabel('Attrition')
plt.ylabel('PercentSalaryHike')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x='Attrition',y='PerformanceRating',data=df)
# Out:
# <Axes: xlabel='Attrition', ylabel='PerformanceRating'>

# %% [markdown]
# Performance rating and percent salary hike do not impact Attrition

# %%
sns.barplot(x='Attrition',y='WorkLifeBalance',data=df)
# Out:
# <Axes: xlabel='Attrition', ylabel='WorkLifeBalance'>

# %% [markdown]
# We can see that people who have a higher index for work life balance tend to stay at the company

# %%
sns.barplot(x='Attrition',y='YearsAtCompany',data=df)
# Out:
# <Axes: xlabel='Attrition', ylabel='YearsAtCompany'>

# %% [markdown]
# Employees who have stayed longer in the company are less prone to leaving.

# %%
sns.barplot(x='Attrition',y='YearsSinceLastPromotion',data=df)
# Out:
# <Axes: xlabel='Attrition', ylabel='YearsSinceLastPromotion'>

# %% [markdown]
# Surprisingly the amount of time since last promotion does not affect the Attrition of an employee

# %%
sns.barplot(x='Attrition',y='PercentSalaryHike',data=df)
# Out:
# <Axes: xlabel='Attrition', ylabel='PercentSalaryHike'>

# %% [markdown]
# Percent of increase in salary doesn't keep an employee in

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))

sns.countplot(x='Gender', hue='Attrition', data=df,palette="Set2")

plt.ylabel('Count')
plt.title('Attrition by Gender')

plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))

sns.countplot(x='Department', hue='Attrition', data=df,palette="Set2")

plt.ylabel('Count')
plt.title('Attrition by Department')
plt.show()

# %% [markdown]
# People at R&D department have the least Attrition

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))

sns.countplot(x='MaritalStatus', hue='Attrition', data=df,palette="Set2")

plt.ylabel('Count')
plt.title('Attrition by Department')
plt.show()

# %% [markdown]
# we can see single people tend to leave the company while married and divorce peole don't.

# %%
fig, ax = plt.subplots()
sns.kdeplot(df.loc[df['Attrition'] == 'No', 'DistanceFromHome'], label = 'Active Employee')
sns.kdeplot(df.loc[df['Attrition'] == 'Yes', 'DistanceFromHome'], label = 'Ex-Employee')
ax.set_xlim(1)
plt.legend()
plt.show()

# %%
corr_matrix = df.select_dtypes(include=['float64', 'int64']).corr()
plt.figure(figsize=(20,10))
sns.heatmap(corr_matrix, cmap="crest", annot=True,)
# Out:
# <Axes: >

# %% [markdown]
# There is a strong positive correlation between Monthly Income and Job Level.
# Job Level demonstrates a strong positive correlation with Total Working Hours.
# Monthly Income is positively correlated with Total Working Hours.
# Age shows a positive correlation with Total Working Hours.
# Marital Status and Stock Option Level exhibit a negative correlation.

# %% [markdown]
# 1.We can confidently say that age, job satisfaction, monthly income, marital status,department, years at company and years in current role along play a huge in employees' attrition.
# 2.Also, Gender, Salary increase percentage and performance ratings are not significantly impacting the employees' decision to leave the company.

# %% [markdown]
# Chi-Square Test of Independence

# %%
import scipy
from scipy.stats import chi2_contingency

# %%
cat_cols=df.select_dtypes(include="category").columns.tolist() 
chi_statistic=[]
p_val=[]
vars_rm=[]

for i in df[cat_cols]:
    observed=pd.crosstab(index=df["Attrition"], columns=df[i])
    stat, p, dof, expected=chi2_contingency(observed)
    chi_statistic.append(stat)
    p_val.append(p)
    if p >= 0.05:
        print("Attrition and {} are independent (p-value = {:.2f}).\n".format(i,p))
        vars_rm.append(i)

# %%
chi_df = pd.DataFrame()
chi_df["Variable"] = cat_cols
chi_df["Chi_Statistic"] = chi_statistic
chi_df["P_value"] = p_val
chi_df=chi_df[chi_df.P_value<0.05].sort_values("P_value", ascending=True)
display(chi_df)
# Out:
# Empty DataFrame
# Columns: [Variable, Chi_Statistic, P_value]
# Index: []
