# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Heart Disease data.csv")
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %% [markdown]
# age: The person's age in years
#
# sex: The person's sex (1 = male, 0 = female)
#
# cp: The chest pain experienced (Value 1: typical angina, Value 2: atypical angina, Value 3: non-anginal pain, Value 4: asymptomatic)
#
# trestbps: The person's resting blood pressure (mm Hg on admission to the hospital)
#
# chol: The person's cholesterol measurement in mg/dl
#
# fbs: The person's fasting blood sugar (> 120 mg/dl, 1 = true; 0 = false)
#
# restecg: Resting electrocardiographic measurement (0 = normal, 1 = having ST-T wave abnormality, 2 = showing probable or definite left ventricular hypertrophy by Estes' criteria)
#
# thalach: The person's maximum heart rate achieved
#
# exang: Exercise induced angina (1 = yes; 0 = no)
#
# oldpeak: ST depression induced by exercise relative to rest
#
# slope: the slope of the peak exercise ST segment (Value 1: upsloping, Value 2: flat, Value 3: downsloping)
#
# ca: The number of major vessels (0-3)
#
# thal: A blood disorder called thalassemia (3 = normal; 6 = fixed defect; 7 = reversable defect)
#
# num: Heart disease (0 = no, 1 = yes)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
obj_columns=df.select_dtypes(include=['object']).columns
numerical_columns=df.select_dtypes(include=['int64','float64']).columns

# %%
obj_columns
# Out:
# Index([], dtype='object')

# %%
numerical_columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
def heart_disease(row):
    if row==0:
        return 'Absence'
    elif row==1:
        return 'Presence'

# %%
df['target'].unique
# Out:
# <bound method Series.unique of 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64>

# %%
df['Heart_Disease']=df['target'].apply(heart_disease)
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target Heart_Disease
# 0   2     3       0       Absence
# 1   0     3       0       Absence
# ...

# %%
def gender(row):
    if row==1:
        return 'Male'
    elif row==0:
        return 'Female'

# %%
df['Gender']=df['sex'].apply(gender)
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target Heart_Disease  Gender
# 0   2     3       0       Absence    Male
# ...

# %%
def age_grp(range):
    if range>=29 and range<40:
        return 'Young Age'
    elif range>=40 and range<55:
        return 'Middle Age'
    elif range>=55:
        return 'Elder Age'

# %%
df['Age_Group']=df['age'].apply(age_grp)
df.head(20)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    52    1   0       125   212    0        1      168      0      1.0
# 1    53    1   0       140   203    1        0      155      1      3.1
# 2    70    1   0       145   174    0        1      125      1      2.6
# 3    61    1   0       148   203    0        1      161      0      0.0
# 4    62    0   0       138   294    1        1      106      0      1.9
# 5    58    0   0       100   248    0        0      122      0      1.0
# 6    58    1   0       114   318    0        2      140      0      4.4
# 7    55    1   0       160   289    0        0      145      1      0.8
# 8    46    1   0       120   249    0        0      144      0      0.8
# 9    54    1   0       122   286    0        0      116      1      3.2
# 10   71    0   0       112   149    0        1      125      0      1.6
# 11   43    0   0       132   341    1        0      136      1      3.0
# ...

# %%
df['cp'].unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
chestpain_mapping = { 0: 'Typical Angina', 1: 'Atypical Angina', 2: 'Non-Anginal Pain', 3: 'Asymptomatic'}

df['cp'] = df['cp'].replace(chestpain_mapping)

# %%
df.rename(columns={'cp': 'chestpain_type','trestbps':'blood_pressure','chol':'cholestrol','ca':'major_vessels','thalach':'max_heart_rate'}, inplace=True)
df
# Out:
#       age  sex   chestpain_type  blood_pressure  cholestrol  fbs  restecg  \
# 0      52    1   Typical Angina             125         212    0        1
# 1      53    1   Typical Angina             140         203    1        0
# 2      70    1   Typical Angina             145         174    0        1
# 3      61    1   Typical Angina             148         203    0        1
# 4      62    0   Typical Angina             138         294    1        1
# ...   ...  ...              ...             ...         ...  ...      ...
# 1020   59    1  Atypical Angina             140         221    0        1
# 1021   60    1   Typical Angina             125         258    0        0
# 1022   47    1   Typical Angina             110         275    0        0
# 1023   50    0   Typical Angina             110         254    0        0
# 1024   54    1   Typical Angina             120         188    0        1
#
#       max_heart_rate  exang  oldpeak  slope  major_vessels  thal  target  \
# ...

# %%
df['chestpain_type'].value_counts()
# Out:
# chestpain_type
# Typical Angina      497
# Non-Anginal Pain    284
# Atypical Angina     167
# Asymptomatic         77
# Name: count, dtype: int64

# %%
df['Age_Group'].value_counts()
# Out:
# Age_Group
# Elder Age     549
# Middle Age    419
# Young Age      57
# Name: count, dtype: int64

# %%
hd=df.groupby('Heart_Disease')['target'].count()
hd
# Out:
# Heart_Disease
# Absence     499
# Presence    526
# Name: target, dtype: int64

# %%
labels = ['Absence', 'Presence']
values = [499, 526]
fig, ax = plt.subplots()
ax.pie(values, labels=labels, autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.4))
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
ax.axis('equal')

plt.title(' Absence/Presence of Heart Disease')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.countplot(x=df['Heart_Disease'], hue='Gender', data=df, palette='BuGn_r')
plt.xlabel('Heart Disease', fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.legend(labels=['Male','Female'])
plt.title('Heart Disease Based on Gender',fontsize=17)
plt.show()

# %%
df_presence = df[df['Heart_Disease'] == 'Presence']
sns.countplot(x='Gender', data=df_presence, palette='viridis')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distribution of Heart Disease (Presence) by Gender')
plt.show()

# %% [markdown]
# male has high number of heart disease

# %%
sns.countplot(x='Age_Group', data=df_presence, palette="dark")
plt.xlabel('Age_Group')
plt.ylabel('Count')
plt.title('Presnce of heart disease by AGe group')
plt.show()

# %% [markdown]
# middle age grp has more heart disease

# %%
#Count Plot Creation of Chest Pain Experienced using MatplotLib and Seaborn

sns.countplot(x=df['Heart_Disease'], hue='chestpain_type', data=df, palette="muted",order=['Presence','Absence'])
plt.title('Chest Pain Experienced', fontsize=17)
plt.xlabel('Heart Disease',fontsize=15)
plt.ylabel('Counts',fontsize=15)
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'])
plt.show()

# %% [markdown]
# Non-anginal chest pain refers to chest discomfort or pain that is not caused by reduced blood flow to the heart muscle, as is the case with angina.Non-anginal chest pain can have various causes that are not directly related to the heart

# %%
sns.countplot(x=df['Gender'], hue='chestpain_type', data=df)
plt.title('Chest Pain Based On Gender', fontsize=17)
plt.xlabel('Gender', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'])
plt.show()

# %% [markdown]
# nmber of men are suffering from typical angina

# %%
df
# Out:
#       age  sex   chestpain_type  blood_pressure  cholestrol  fbs  restecg  \
# 0      52    1   Typical Angina             125         212    0        1
# 1      53    1   Typical Angina             140         203    1        0
# 2      70    1   Typical Angina             145         174    0        1
# 3      61    1   Typical Angina             148         203    0        1
# 4      62    0   Typical Angina             138         294    1        1
# ...   ...  ...              ...             ...         ...  ...      ...
# 1020   59    1  Atypical Angina             140         221    0        1
# 1021   60    1   Typical Angina             125         258    0        0
# 1022   47    1   Typical Angina             110         275    0        0
# 1023   50    0   Typical Angina             110         254    0        0
# 1024   54    1   Typical Angina             120         188    0        1
#
#       max_heart_rate  exang  oldpeak  slope  major_vessels  thal  target  \
# ...

# %%
numeric_data = df.select_dtypes(include='number')

# Create the heatmap
plt.figure(figsize=(16, 9))
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm',linewidth=3)
plt.show()

# %%
plt.scatter(df['blood_pressure'], df['Heart_Disease'], marker='o', linestyle='-', color='b', label='Presence of Heart Disease')
plt.xlabel('blood_pressure')
plt.ylabel('Presence of Heart Disease')
plt.title('Correlation between blood_pressuree and Heart Disease')
plt.legend()
plt.show()

# %%
sns.barplot(x='Gender', y='blood_pressure', data=df, palette='hls')
plt.title("blood_pressure Based On Gender", fontsize=17)
plt.xlabel('Gender',fontsize=15)
plt.ylabel("blood_pressure", fontsize=15)
plt.show()

# %% [markdown]
# female has more blood_pressure
# female has more cholestrol

# %%
sns.barplot(x='Gender', y='cholestrol', data=df, palette='hls')
plt.title("Cholestrol Level Based On Gender", fontsize=17)
plt.xlabel('Gender',fontsize=15)
plt.ylabel("Cholestrol", fontsize=15)
plt.show()

# %%
plt.scatter(df['cholestrol'], df['Heart_Disease'], marker='o', linestyle='-', color='b', label='Presence of Heart Disease')
plt.xlabel('cholestrol')
plt.ylabel('Presence of Heart Disease')
plt.title('Correlation between cholestrol and Heart Disease')
plt.legend()
plt.show()

# %% [markdown]
# ##persons whoose cholestrol ranges from 200-400 has heart disease

# %%
plt.scatter(df['max_heart_rate'], df['Heart_Disease'], marker='o',linestyle='-', color='b', label='Presence of Heart Disease')
plt.xlabel('max_heart_rate')
plt.ylabel('Presence of Heart Disease')
plt.title('Correlation between max_heart_rate and Heart Disease')
plt.legend()
plt.show()

# %% [markdown]
# ##persons whooseheart rate ranges from 140-200 has heart disease

# %%
#Bar Plot Creation of Fasting Blood Sugar VS Gender using MatplotLib and Seaborn

sns.barplot(y='fbs', x='Gender', data=df, palette='husl')
plt.title(' Fasting Blood Sugar VS Gender', fontsize=17)
plt.xlabel('Gender', fontsize=15)
plt.ylabel('Fasting Blood Sugar', fontsize=15)
plt.show()

# %% [markdown]
# Males have high no of Fasting Blood Sugar over 120

# %%
plt.scatter(df['fbs'], df['Heart_Disease'], marker='o', linestyle='-', color='b', label='Presence of Heart Disease')
plt.xlabel('Fasting blood Sugar')
plt.ylabel('Presence of Heart Disease')
plt.title('Correlation between Fasting blood Sugar and Heart Disease')
plt.legend()
plt.show()

# %% [markdown]
# ##persons having blood sugar >120 has risk of haert disease

# %%
plt.scatter(df['thal'], df['Heart_Disease'], marker='o', linestyle='-', color='b', label='Presence of Heart Disease')
plt.xlabel('thalassemia')
plt.ylabel('Presence of Heart Disease')
plt.title('Correlation between thalassemia and Heart Disease')
plt.legend()
plt.show()

# %% [markdown]
# ##thal is not a  good attribute to understand the correlation

# %%
plt.scatter(df['thal'], df['Heart_Disease'], marker='o', linestyle='-', color='b', label='Presence of Heart Disease')
plt.xlabel('thalassemia')
plt.ylabel('Presence of Heart Disease')
plt.title('Correlation between thalassemia and Heart Disease')
plt.legend()
plt.show()

# %%
sns.lineplot(x='age', y='blood_pressure', data=df, color='r')
plt.title('Blood Pressure VS Age', fontsize=17)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Blood Pressure', fontsize=15)
plt.show()

# %% [markdown]
# Here we can observe that Blood Pressure increases between age of 50 to 60 and somehow continue the pattern till 70

# %%
sns.lineplot(x='age', y='cholestrol', data=df, color='b')
plt.title('Cholestrol VS Age', fontsize=17)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Cholestrol', fontsize=15)
plt.show()

# %% [markdown]
# -> Similarly Cholestrol Increasing in the age group of 50-60

# %%
sns.lineplot(x='age', y='oldpeak', data=df, color='g')
plt.title('ST Depression VS Age', fontsize=17)
plt.xlabel('Age', fontsize=15)
plt.ylabel('ST depression', fontsize=15)
plt.show()

# %% [markdown]
# -> we can observe from here that ST depression mostly increases bw the age group of 30-40
# -> ST depression refers to a finding on an electrocardiogram, wherein the trace in the ST segment is abnormally low below the baseline.
